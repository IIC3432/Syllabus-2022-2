# %% [markdown]
# Volvemos a cargar el dataset y una serie de otras cosas.
#
# Basado en este excelente [tutorial](https://keras.io/examples/graph/gnn_citations/).

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

citations = pd.read_csv("cora/cora.cites",
    sep="\t",
    header=None,
    names=["target", "source"],
)

column_names = ["paper_id"] + [f"term_{idx}" for idx in range(1433)] + ["subject"]
papers = pd.read_csv("cora/cora.content", sep="\t", header=None, names=column_names,
)

# %%
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (1339, 1435)
# Test data shape: (1369, 1435)

# %%
train_data
# Out:
#       paper_id  term_0  term_1  term_2  term_3  term_4  term_5  term_6  \
# 1797      1641       0       0       0       0       0       0       0
# 104       1128       0       0       0       0       0       0       0
# 343        486       0       0       0       0       0       0       0
# 1576      2243       0       0       0       0       0       0       0
# 1496        38       0       0       0       0       0       0       0
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 1079       384       0       0       0       0       0       0       0
# 2694      1857       0       0       0       0       0       0       0
# 1319      1383       0       0       0       0       0       0       0
# 1369      2523       0       0       0       0       0       0       0
# 2435      2530       0       0       0       0       0       0       0
#
#       term_7  term_8  ...  term_1424  term_1425  term_1426  term_1427  \
# 1797       0       0  ...          0          0          0          0
# 104        0       0  ...          0          0          0          0
# 343        0       0  ...          0          0          0          0
# 1576       0       0  ...          0          0          1          0
# 1496       0       0  ...          0          0          0          0
# ...      ...     ...  ...        ...        ...        ...        ...
# 1079       0       0  ...          0          0          0          0
# 2694       0       0  ...          0          0          1          0
# 1319       0       0  ...          0          0          0          0
# 1369       0       0  ...          0          0          0          0
# 2435       0       0  ...          0          0          0          0
#
#       term_1428  term_1429  term_1430  term_1431  term_1432  subject
# 1797          0          0          0          0          0        1
# 104           0          0          0          0          0        2
# 343           0          0          0          0          0        1
# 1576          0          0          0          0          0        6
# 1496          0          0          0          0          0        0
# ...         ...        ...        ...        ...        ...      ...
# 1079          0          0          0          0          0        2
# 2694          0          0          0          0          0        6
# 1319          0          0          0          0          0        1
# 1369          0          0          0          0          0        1
# 2435          0          0          0          0          0        2
#
# [1339 rows x 1435 columns]

# %%
def create_MLP(capas_internas, dropout_rate, name=None):
    capas = []

    for capa_interna in capas_internas:
        capas.append(layers.BatchNormalization())
        capas.append(layers.Dropout(dropout_rate))
        capas.append(layers.Dense(capa_interna, activation=tf.nn.gelu))

    return keras.Sequential(capas, name=name)

# %% [markdown]
# ## Manejo de datos específico para nuestras GNNs.
#
# Lo primero es que ahora las GNNs van a funcionar en base a las conexiones entro los papers (además de los features obviamente). La GNN se compila con la info del grado, por lo que el x_train y x_test solo deben tener los id de los nodos relevantes.

# %%
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data["paper_id"].to_numpy()
x_test = test_data["paper_id"].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %% [markdown]
# El segundo paso es crear una matriz de adyacencia en formato numpy, que es lo que vamos a necesitar para pasarselo a tensorflow. Por razones de formato, es mejor usar una representación esparsa, en forma de lista de pares.

# %%
#Matriz en forma de lista de pares
edges = citations[["source", "target"]].to_numpy().T

#Codigo para agregar peso a cada arista, por ahora son puros 1s, todas valen lo mismo. 
edge_weights = tf.ones(shape=edges.shape[1])

# Crear (en formato tensowrflow) los features para cada nodo.
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)

#### juan: esto se puede simplificar
# el grafo es la union de estas tres cosas
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Nodes shape:", node_features.shape)


### Esto es muy importante. 
### El primer vector es la lista de los indices de los nodos source de edges, 
### El segundo vector es la lista de los indices de los nodos target

node_indices, neighbour_indices = edges[0], edges[1]
# Out:
# Edges shape: (2, 5429)
# Nodes shape: (2708, 1433)

# %% [markdown]
# ### Un modelo para una capa de la GNN
#
# Esta es la capa que va a hacer los pasos de agregación y update.
# Lamentablemente, la estructura de tensorflow nos obliga a definir estas operaciones, bastante complejas, como otras layers, por lo que procedemos a extender la clase *Layer*. Lo bueno es que funciona prácticamente igual que un *Model*.

# %%
class GNNlayer(layers.Layer):
    def __init__(
        self,
        capas_internas = [32,32],
        dropout_rate=0.2,
        normalize=False,
        *args,
        **kwargs,
    ):
        super(GNNlayer, self).__init__(*args, **kwargs)

        #Hay dos redes neuronales involucradas en una capa de GNN: la primera activación de los mensajes, 
        #    y el manejo del update. 
            
        self.preprocesador = create_MLP(capas_internas, dropout_rate)

        self.updater = create_MLP(capas_internas, dropout_rate)

        
    def prepare(self, node_repesentations, weights=None):
        
#        Esta funcion pasa los mensajes por una red neuronal simple, y aplica los pesos (si hay)
        
        messages = self.preprocesador(node_repesentations)
        messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages, node_repesentations):
        
        # Esta funcion agrega los mensajes de cada nodo, en forma de suma. 
        # recibo un vector node_indices, que es de largo [num_edges] y me dice los nodos origen de cada arista
        # matriz neighbour_messages es de forma [num_edges, (neuronas_internas)], osea [num_edges, 32] en este codigo
        # esta matriz tiene el mensaje de cada nodo que participa en la arista como nodo destino
        # la matriz node_repesentations es de la forma [num_nodes, representation_dim], contiene información de 
        # los nodos del grafo. 
        
        num_nodes = node_repesentations.shape[0]
        
                
        #### La funcion unsorted_segment_sum me suma los mensajes de todos los indices iguales en node_indices y 
        #### los deja en el i-esimo lugar; con eso sumamos los ids. Si un nodo no tiene vecinos recibe un 0
        
        aggregated_message = tf.math.unsorted_segment_sum(
            neighbour_messages, node_indices, num_segments=num_nodes
        )
        
        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        
        # Para combinar los mensajes con los features de cada nodo, concatenamos. 
        # Notar que a este punto tanto node_repesentations como aggregated_messages tienen forma 
        # [num_nodes, representation_dim]. Concat me los concatena. 

        h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        
        # Y aplicamos unas capas no-lineales
        
        node_embeddings = self.updater(h)

        return node_embeddings

    def call(self, inputs):
        ## Procesa los inputs para crear los embeddings. Siempre tenemos información de todo el grafo, 
        ## y operamos sobre todos los nodos en node_representations

        node_repesentations, edges, edge_weights = inputs
        
        node_indices, neighbour_indices = edges[0], edges[1]
        
        # Lo primero es una lista de vectores en donde tomo cada id en neighbour_indices 
        # y lo reemplazo por la representación de ese id. 
        # El resultado es una lista que contiene, para cada arista, la representación del target de esa arista. 
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Procesamos estos mensajes (posiblemente incluyendo pesos en aristas)
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)
        
        #Los agregamos
        aggregated_messages = self.aggregate(
            node_indices, neighbour_messages, node_repesentations
        )
        
        # Y finalmente, el update. 
        return self.update(node_repesentations, aggregated_messages)

# %% [markdown]
# ## Juntando todo en un clasificador
#
# Ahora si, definimos un modelo igual que la vez anterior, solo que ahora usa nuestra capa!

# %%
class GNNbasica(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        capas_internas = [32,32],
        dropout_rate=0.2,
        normalize=True,
        *args,
        **kwargs,
    ):
        
        super(GNNbasica, self).__init__(*args, **kwargs)

#LA GNN maneja información de todo el grafo, independiente del batch que procese. 

        node_features, edges, edge_weights = graph_info
        self.node_features = node_features
        self.edges = edges
        self.edge_weights = edge_weights
        
        #normalizar
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

#Las layers básicas: una capa para preprocesar todo        
        self.preprocesar = create_MLP(capas_internas, dropout_rate, name="preprocesado")
    
# dos capas de paso de mensjaes 

        self.capa1 = GNNlayer(
            capas_internas,
            dropout_rate,
            name="capa1",
        )
        # Create the second GraphConv layer.
        self.capa2 = GNNlayer(
            capas_internas,
            dropout_rate,
            name="capa2",
        )
        
        # Create a postprocess layer.
        self.postprocess = create_MLP(capas_internas, dropout_rate, name="postprocess")
        # Create a compute logits layer.
        self.clas = layers.Dense(units=num_classes, name="logits")

        
    def call(self, batch_indices):
        
        #### Capa de preprocesado de features, para bajar la dimensionalidad
        
        nodos_preprocesados = self.preprocesar(self.node_features)
        
        #### Estos nodos preprocesados pasan por la capa1, la que agrega los mensajes de sus vecinos. 
            
        paso_mens1 = self.capa1((nodos_preprocesados,self.edges, self.edge_weights))
        
        skip1 = nodos_preprocesados + paso_mens1 
        
        paso_mens2 = self.capa2((skip1,self.edges, self.edge_weights))
        
        skip2 = paso_mens2 + skip1

        ##### Postprocesado y llegar a la categoría del nodo
        postprocesado = self.postprocess(skip2)

        ##### Volvemos a poner los embeddings en el orden que demandaba segun el batch
        node_embeddings = tf.gather(postprocesado, batch_indices)

        # Readout para llegar a las categorias
        
        return self.clas(node_embeddings)

# %%
GNN = GNNbasica(
    graph_info=graph_info,
    num_classes=7,
    capas_internas=[32,32],
    dropout_rate=0.2,
    name="gnn_model",
)

print(GNN([1, 10, 100]))

GNN.summary()
# Out:
# tf.Tensor(
# [[ 0.00584892 -0.00288862  0.00569667  0.00325591 -0.00820563  0.00216732
#    0.00964786]
#  [-0.00398662  0.00535307  0.01238073 -0.00801736 -0.00595177 -0.01417633
#   -0.02469733]
#  [-0.00247852 -0.01235869  0.02197962  0.00418749 -0.00448587  0.00957375
#   -0.01504638]], shape=(3, 7), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocesado (Sequential)   (2708, 32)                52804
#
#  capa1 (GNNlayer)            multiple                  5888
#
#  capa2 (GNNlayer)            multiple                  5888
#
#  postprocess (Sequential)    (2708, 32)                2368
#
#  logits (Dense)              multiple                  231
#
# =================================================================
# Total params: 67,179
# Trainable params: 63,481
# Non-trainable params: 3,698
# _________________________________________________________________

# %%
GNN.compile(
        optimizer=keras.optimizers.Adam(0.01),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    )

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_acc", patience=50, restore_best_weights=True
    )

# A la GNN hay que darlos los ids de los nodos 


    # Fit the model.
history = GNN.fit(
        x=x_train,
        y=y_train,
        epochs=300,
        batch_size=256,
        validation_split=0.15,
        callbacks=[early_stopping],
    )
# Out:
# Epoch 1/300
# 5/5 [==============================] - 4s 192ms/step - loss: 2.1214 - acc: 0.1740 - val_loss: 1.8832 - val_acc: 0.3085
# Epoch 2/300
# 5/5 [==============================] - 0s 89ms/step - loss: 1.8702 - acc: 0.2830 - val_loss: 1.8421 - val_acc: 0.3085
# Epoch 3/300
# 5/5 [==============================] - 0s 91ms/step - loss: 1.7483 - acc: 0.3348 - val_loss: 1.7986 - val_acc: 0.3284
# Epoch 4/300
# 5/5 [==============================] - 0s 93ms/step - loss: 1.6265 - acc: 0.3787 - val_loss: 1.7132 - val_acc: 0.3333
# Epoch 5/300
# 5/5 [==============================] - 0s 91ms/step - loss: 1.4899 - acc: 0.4605 - val_loss: 1.6001 - val_acc: 0.3383
# Epoch 6/300
# 5/5 [==============================] - 0s 91ms/step - loss: 1.3056 - acc: 0.5299 - val_loss: 1.5505 - val_acc: 0.3682
# Epoch 7/300
# 5/5 [==============================] - 0s 90ms/step - loss: 1.1717 - acc: 0.5844 - val_loss: 1.5749 - val_acc: 0.3632
# Epoch 8/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.9464 - acc: 0.6740 - val_loss: 1.5976 - val_acc: 0.3930
# Epoch 9/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.8037 - acc: 0.7232 - val_loss: 1.7045 - val_acc: 0.3930
# Epoch 10/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6658 - acc: 0.7873 - val_loss: 1.9872 - val_acc: 0.3731
# Epoch 11/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.5006 - acc: 0.8339 - val_loss: 2.0405 - val_acc: 0.4179
# Epoch 12/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4914 - acc: 0.8357 - val_loss: 2.4322 - val_acc: 0.4229
# Epoch 13/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3397 - acc: 0.8989 - val_loss: 2.6050 - val_acc: 0.4328
# Epoch 14/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.3011 - acc: 0.9104 - val_loss: 2.1461 - val_acc: 0.4925
# Epoch 15/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.2682 - acc: 0.9095 - val_loss: 2.0326 - val_acc: 0.5174
# Epoch 16/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.2026 - acc: 0.9367 - val_loss: 1.7239 - val_acc: 0.5572
# Epoch 17/300
# 5/5 [==============================] - 0s 101ms/step - loss: 0.2381 - acc: 0.9271 - val_loss: 1.6223 - val_acc: 0.5871
# Epoch 18/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1739 - acc: 0.9473 - val_loss: 1.5949 - val_acc: 0.5821
# Epoch 19/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1479 - acc: 0.9605 - val_loss: 1.8065 - val_acc: 0.5672
# Epoch 20/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1274 - acc: 0.9622 - val_loss: 1.8968 - val_acc: 0.5522
# Epoch 21/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.1116 - acc: 0.9649 - val_loss: 2.7960 - val_acc: 0.4776
# Epoch 22/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1031 - acc: 0.9710 - val_loss: 2.7026 - val_acc: 0.4925
# Epoch 23/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1138 - acc: 0.9613 - val_loss: 2.7929 - val_acc: 0.4876
# Epoch 24/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0946 - acc: 0.9736 - val_loss: 2.2606 - val_acc: 0.5323
# Epoch 25/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1110 - acc: 0.9701 - val_loss: 1.6742 - val_acc: 0.6119
# Epoch 26/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0788 - acc: 0.9719 - val_loss: 1.7309 - val_acc: 0.6368
# Epoch 27/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0871 - acc: 0.9798 - val_loss: 1.6089 - val_acc: 0.6368
# Epoch 28/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0736 - acc: 0.9780 - val_loss: 1.4050 - val_acc: 0.6816
# Epoch 29/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0893 - acc: 0.9701 - val_loss: 1.1766 - val_acc: 0.7164
# Epoch 30/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0585 - acc: 0.9815 - val_loss: 1.1861 - val_acc: 0.7114
# Epoch 31/300
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0395 - acc: 0.9903 - val_loss: 1.2866 - val_acc: 0.7065
# Epoch 32/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0622 - acc: 0.9842 - val_loss: 1.2914 - val_acc: 0.6915
# Epoch 33/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0615 - acc: 0.9833 - val_loss: 1.3839 - val_acc: 0.6915
# Epoch 34/300
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0718 - acc: 0.9815 - val_loss: 1.6728 - val_acc: 0.6517
# Epoch 35/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0535 - acc: 0.9815 - val_loss: 1.3585 - val_acc: 0.7114
# Epoch 36/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0685 - acc: 0.9789 - val_loss: 1.5190 - val_acc: 0.6468
# Epoch 37/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0631 - acc: 0.9798 - val_loss: 1.6748 - val_acc: 0.6020
# Epoch 38/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0620 - acc: 0.9798 - val_loss: 1.5642 - val_acc: 0.6766
# Epoch 39/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0472 - acc: 0.9842 - val_loss: 1.2393 - val_acc: 0.7363
# Epoch 40/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0704 - acc: 0.9763 - val_loss: 1.2908 - val_acc: 0.7065
# Epoch 41/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0545 - acc: 0.9824 - val_loss: 1.5972 - val_acc: 0.6617
# Epoch 42/300
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0472 - acc: 0.9842 - val_loss: 1.5717 - val_acc: 0.6766
# Epoch 43/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0490 - acc: 0.9842 - val_loss: 1.4814 - val_acc: 0.7015
# Epoch 44/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0511 - acc: 0.9895 - val_loss: 1.4316 - val_acc: 0.6965
# Epoch 45/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0382 - acc: 0.9877 - val_loss: 1.4277 - val_acc: 0.6766
# Epoch 46/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0562 - acc: 0.9833 - val_loss: 1.6450 - val_acc: 0.6418
# Epoch 47/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0629 - acc: 0.9833 - val_loss: 1.9999 - val_acc: 0.6219
# Epoch 48/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0614 - acc: 0.9833 - val_loss: 1.9062 - val_acc: 0.6517
# Epoch 49/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0450 - acc: 0.9868 - val_loss: 1.3189 - val_acc: 0.7114
# Epoch 50/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0488 - acc: 0.9824 - val_loss: 1.3536 - val_acc: 0.7264
# Epoch 51/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0584 - acc: 0.9842 - val_loss: 1.8105 - val_acc: 0.6567
# Epoch 52/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0524 - acc: 0.9833 - val_loss: 1.5318 - val_acc: 0.6866
# Epoch 53/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0577 - acc: 0.9824 - val_loss: 1.0332 - val_acc: 0.7512
# Epoch 54/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0375 - acc: 0.9859 - val_loss: 0.9253 - val_acc: 0.7562
# Epoch 55/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0453 - acc: 0.9851 - val_loss: 1.0028 - val_acc: 0.7313
# Epoch 56/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0528 - acc: 0.9833 - val_loss: 1.0662 - val_acc: 0.7363
# Epoch 57/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0409 - acc: 0.9877 - val_loss: 1.9954 - val_acc: 0.6020
# Epoch 58/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0513 - acc: 0.9868 - val_loss: 1.9660 - val_acc: 0.5920
# Epoch 59/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0519 - acc: 0.9815 - val_loss: 1.5091 - val_acc: 0.6866
# Epoch 60/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0449 - acc: 0.9859 - val_loss: 1.2181 - val_acc: 0.7313
# Epoch 61/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0405 - acc: 0.9877 - val_loss: 1.1577 - val_acc: 0.7463
# Epoch 62/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0462 - acc: 0.9851 - val_loss: 1.1141 - val_acc: 0.7562
# Epoch 63/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0300 - acc: 0.9903 - val_loss: 1.0563 - val_acc: 0.7662
# Epoch 64/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0461 - acc: 0.9868 - val_loss: 1.0469 - val_acc: 0.7612
# Epoch 65/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0652 - acc: 0.9842 - val_loss: 1.0717 - val_acc: 0.7711
# Epoch 66/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0356 - acc: 0.9912 - val_loss: 1.1687 - val_acc: 0.7662
# Epoch 67/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0198 - acc: 0.9938 - val_loss: 1.4109 - val_acc: 0.7264
# Epoch 68/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0401 - acc: 0.9886 - val_loss: 1.1859 - val_acc: 0.7512
# Epoch 69/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0327 - acc: 0.9903 - val_loss: 1.0909 - val_acc: 0.7662
# Epoch 70/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0199 - acc: 0.9938 - val_loss: 1.1840 - val_acc: 0.7612
# Epoch 71/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0366 - acc: 0.9895 - val_loss: 1.1293 - val_acc: 0.7363
# Epoch 72/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0190 - acc: 0.9947 - val_loss: 1.1992 - val_acc: 0.7463
# Epoch 73/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0241 - acc: 0.9903 - val_loss: 1.2765 - val_acc: 0.7463
# Epoch 74/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0447 - acc: 0.9868 - val_loss: 1.1322 - val_acc: 0.7910
# Epoch 75/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0266 - acc: 0.9895 - val_loss: 1.0756 - val_acc: 0.7861
# Epoch 76/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0324 - acc: 0.9895 - val_loss: 1.1420 - val_acc: 0.7363
# Epoch 77/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0293 - acc: 0.9912 - val_loss: 1.0990 - val_acc: 0.7612
# Epoch 78/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0149 - acc: 0.9938 - val_loss: 1.0666 - val_acc: 0.7711
# Epoch 79/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0219 - acc: 0.9947 - val_loss: 1.0638 - val_acc: 0.7910
# Epoch 80/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0308 - acc: 0.9912 - val_loss: 0.9938 - val_acc: 0.8159
# Epoch 81/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0301 - acc: 0.9921 - val_loss: 1.0037 - val_acc: 0.8308
# Epoch 82/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0236 - acc: 0.9938 - val_loss: 0.9589 - val_acc: 0.8358
# Epoch 83/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0321 - acc: 0.9921 - val_loss: 0.9692 - val_acc: 0.8060
# Epoch 84/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0299 - acc: 0.9912 - val_loss: 1.1174 - val_acc: 0.8010
# Epoch 85/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0237 - acc: 0.9912 - val_loss: 1.2011 - val_acc: 0.7960
# Epoch 86/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0399 - acc: 0.9877 - val_loss: 1.2736 - val_acc: 0.7910
# Epoch 87/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0211 - acc: 0.9947 - val_loss: 1.0801 - val_acc: 0.8060
# Epoch 88/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0173 - acc: 0.9956 - val_loss: 1.0165 - val_acc: 0.8159
# Epoch 89/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0688 - acc: 0.9851 - val_loss: 0.9862 - val_acc: 0.8259
# Epoch 90/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0265 - acc: 0.9903 - val_loss: 1.0157 - val_acc: 0.8408
# Epoch 91/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0342 - acc: 0.9921 - val_loss: 1.0958 - val_acc: 0.8209
# Epoch 92/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0267 - acc: 0.9947 - val_loss: 1.1562 - val_acc: 0.7910
# Epoch 93/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0260 - acc: 0.9930 - val_loss: 1.0348 - val_acc: 0.8060
# Epoch 94/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0238 - acc: 0.9938 - val_loss: 0.9459 - val_acc: 0.8109
# Epoch 95/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0288 - acc: 0.9956 - val_loss: 1.0777 - val_acc: 0.7910
# Epoch 96/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0290 - acc: 0.9921 - val_loss: 1.2990 - val_acc: 0.7811
# Epoch 97/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0333 - acc: 0.9877 - val_loss: 1.4206 - val_acc: 0.7711
# Epoch 98/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0555 - acc: 0.9886 - val_loss: 1.4097 - val_acc: 0.7512
# Epoch 99/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0439 - acc: 0.9895 - val_loss: 1.0962 - val_acc: 0.8159
# Epoch 100/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0212 - acc: 0.9938 - val_loss: 1.0099 - val_acc: 0.8159
# Epoch 101/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0351 - acc: 0.9895 - val_loss: 1.0002 - val_acc: 0.8209
# Epoch 102/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0252 - acc: 0.9912 - val_loss: 1.0021 - val_acc: 0.8259
# Epoch 103/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0442 - acc: 0.9868 - val_loss: 1.0677 - val_acc: 0.8209
# Epoch 104/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0266 - acc: 0.9930 - val_loss: 1.0725 - val_acc: 0.8209
# Epoch 105/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0228 - acc: 0.9947 - val_loss: 1.0867 - val_acc: 0.8209
# Epoch 106/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0371 - acc: 0.9877 - val_loss: 1.1382 - val_acc: 0.8010
# Epoch 107/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0426 - acc: 0.9877 - val_loss: 1.0594 - val_acc: 0.8159
# Epoch 108/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0300 - acc: 0.9903 - val_loss: 1.0406 - val_acc: 0.8308
# Epoch 109/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0253 - acc: 0.9930 - val_loss: 1.0047 - val_acc: 0.8507
# Epoch 110/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0275 - acc: 0.9938 - val_loss: 0.9766 - val_acc: 0.8308
# Epoch 111/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0194 - acc: 0.9930 - val_loss: 0.9195 - val_acc: 0.8259
# Epoch 112/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0358 - acc: 0.9903 - val_loss: 0.9278 - val_acc: 0.8209
# Epoch 113/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0274 - acc: 0.9921 - val_loss: 1.0055 - val_acc: 0.8358
# Epoch 114/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0245 - acc: 0.9921 - val_loss: 1.0173 - val_acc: 0.8308
# Epoch 115/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0404 - acc: 0.9868 - val_loss: 1.0934 - val_acc: 0.8209
# Epoch 116/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0385 - acc: 0.9912 - val_loss: 1.1412 - val_acc: 0.8209
# Epoch 117/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0162 - acc: 0.9947 - val_loss: 1.0470 - val_acc: 0.8308
# Epoch 118/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0280 - acc: 0.9921 - val_loss: 0.9919 - val_acc: 0.8408
# Epoch 119/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0418 - acc: 0.9868 - val_loss: 0.9737 - val_acc: 0.8507
# Epoch 120/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0297 - acc: 0.9903 - val_loss: 0.9789 - val_acc: 0.8458
# Epoch 121/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0249 - acc: 0.9938 - val_loss: 1.0502 - val_acc: 0.8259
# Epoch 122/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0192 - acc: 0.9956 - val_loss: 1.0831 - val_acc: 0.8209
# Epoch 123/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0210 - acc: 0.9921 - val_loss: 1.0682 - val_acc: 0.8159
# Epoch 124/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0202 - acc: 0.9938 - val_loss: 1.0400 - val_acc: 0.8308
# Epoch 125/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0182 - acc: 0.9938 - val_loss: 1.0417 - val_acc: 0.8308
# Epoch 126/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0143 - acc: 0.9965 - val_loss: 1.0521 - val_acc: 0.8408
# Epoch 127/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0212 - acc: 0.9921 - val_loss: 1.0629 - val_acc: 0.8358
# Epoch 128/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0498 - acc: 0.9868 - val_loss: 1.0571 - val_acc: 0.8358
# Epoch 129/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0220 - acc: 0.9930 - val_loss: 1.1538 - val_acc: 0.8159
# Epoch 130/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0262 - acc: 0.9877 - val_loss: 1.1046 - val_acc: 0.8308
# Epoch 131/300
# 5/5 [==============================] - 0s 104ms/step - loss: 0.0252 - acc: 0.9886 - val_loss: 1.1925 - val_acc: 0.8358
# Epoch 132/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0392 - acc: 0.9895 - val_loss: 1.1186 - val_acc: 0.8308
# Epoch 133/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0272 - acc: 0.9921 - val_loss: 1.0546 - val_acc: 0.8358
# Epoch 134/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0176 - acc: 0.9956 - val_loss: 1.0337 - val_acc: 0.8259
# Epoch 135/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0133 - acc: 0.9974 - val_loss: 1.0264 - val_acc: 0.8308
# Epoch 136/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0437 - acc: 0.9921 - val_loss: 1.0361 - val_acc: 0.8308
# Epoch 137/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0128 - acc: 0.9982 - val_loss: 1.1160 - val_acc: 0.8458
# Epoch 138/300
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0236 - acc: 0.9947 - val_loss: 1.1779 - val_acc: 0.8458
# Epoch 139/300
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0216 - acc: 0.9965 - val_loss: 1.2352 - val_acc: 0.8308
# Epoch 140/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0296 - acc: 0.9947 - val_loss: 1.3109 - val_acc: 0.8010
# Epoch 141/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0172 - acc: 0.9956 - val_loss: 1.1684 - val_acc: 0.7811
# Epoch 142/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0284 - acc: 0.9947 - val_loss: 1.0304 - val_acc: 0.7960
# Epoch 143/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0240 - acc: 0.9947 - val_loss: 1.0133 - val_acc: 0.8159
# Epoch 144/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0198 - acc: 0.9956 - val_loss: 1.0862 - val_acc: 0.8209
# Epoch 145/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0285 - acc: 0.9938 - val_loss: 1.2023 - val_acc: 0.8109
# Epoch 146/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0254 - acc: 0.9912 - val_loss: 1.1885 - val_acc: 0.8109
# Epoch 147/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0311 - acc: 0.9921 - val_loss: 1.0863 - val_acc: 0.8308
# Epoch 148/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0259 - acc: 0.9930 - val_loss: 0.9501 - val_acc: 0.8507
# Epoch 149/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0202 - acc: 0.9938 - val_loss: 0.9031 - val_acc: 0.8458
# Epoch 150/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0151 - acc: 0.9956 - val_loss: 0.9456 - val_acc: 0.8557
# Epoch 151/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0106 - acc: 0.9982 - val_loss: 1.0104 - val_acc: 0.8507
# Epoch 152/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0171 - acc: 0.9956 - val_loss: 0.9995 - val_acc: 0.8358
# Epoch 153/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0148 - acc: 0.9947 - val_loss: 0.9868 - val_acc: 0.8557
# Epoch 154/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0083 - acc: 0.9991 - val_loss: 0.9993 - val_acc: 0.8557
# Epoch 155/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0461 - acc: 0.9912 - val_loss: 1.0916 - val_acc: 0.8358
# Epoch 156/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0287 - acc: 0.9947 - val_loss: 1.1103 - val_acc: 0.8458
# Epoch 157/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0276 - acc: 0.9938 - val_loss: 1.0655 - val_acc: 0.8557
# Epoch 158/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0161 - acc: 0.9956 - val_loss: 1.0878 - val_acc: 0.8507
# Epoch 159/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0169 - acc: 0.9938 - val_loss: 1.1259 - val_acc: 0.8408
# Epoch 160/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0314 - acc: 0.9895 - val_loss: 1.2292 - val_acc: 0.8209
# Epoch 161/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0201 - acc: 0.9912 - val_loss: 1.3354 - val_acc: 0.8060
# Epoch 162/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0164 - acc: 0.9947 - val_loss: 1.2708 - val_acc: 0.8109
# Epoch 163/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0215 - acc: 0.9930 - val_loss: 1.2208 - val_acc: 0.8109
# Epoch 164/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0238 - acc: 0.9938 - val_loss: 1.1925 - val_acc: 0.8159
# Epoch 165/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0282 - acc: 0.9886 - val_loss: 1.2008 - val_acc: 0.8308
# Epoch 166/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0216 - acc: 0.9947 - val_loss: 1.1512 - val_acc: 0.8408
# Epoch 167/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0065 - acc: 0.9982 - val_loss: 1.1198 - val_acc: 0.8408
# Epoch 168/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0140 - acc: 0.9938 - val_loss: 1.0889 - val_acc: 0.8458
# Epoch 169/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0211 - acc: 0.9921 - val_loss: 1.1257 - val_acc: 0.8458
# Epoch 170/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0086 - acc: 0.9974 - val_loss: 1.2611 - val_acc: 0.8358
# Epoch 171/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0179 - acc: 0.9956 - val_loss: 1.1759 - val_acc: 0.8358
# Epoch 172/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0098 - acc: 0.9965 - val_loss: 1.1101 - val_acc: 0.8458
# Epoch 173/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0196 - acc: 0.9938 - val_loss: 1.0724 - val_acc: 0.8358
# Epoch 174/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0276 - acc: 0.9921 - val_loss: 1.0888 - val_acc: 0.8557
# Epoch 175/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0259 - acc: 0.9930 - val_loss: 1.1214 - val_acc: 0.8507
# Epoch 176/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0067 - acc: 0.9982 - val_loss: 1.1391 - val_acc: 0.8408
# Epoch 177/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0194 - acc: 0.9912 - val_loss: 1.1500 - val_acc: 0.8408
# Epoch 178/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0273 - acc: 0.9930 - val_loss: 1.1434 - val_acc: 0.8557
# Epoch 179/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0230 - acc: 0.9938 - val_loss: 1.1152 - val_acc: 0.8458
# Epoch 180/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0272 - acc: 0.9912 - val_loss: 1.1014 - val_acc: 0.8607
# Epoch 181/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0233 - acc: 0.9903 - val_loss: 1.1070 - val_acc: 0.8408
# Epoch 182/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0216 - acc: 0.9947 - val_loss: 1.0698 - val_acc: 0.8408
# Epoch 183/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0140 - acc: 0.9947 - val_loss: 1.1014 - val_acc: 0.8408
# Epoch 184/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0212 - acc: 0.9938 - val_loss: 1.1667 - val_acc: 0.8408
# Epoch 185/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0089 - acc: 0.9982 - val_loss: 1.2172 - val_acc: 0.8458
# Epoch 186/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0173 - acc: 0.9930 - val_loss: 1.1945 - val_acc: 0.8358
# Epoch 187/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0164 - acc: 0.9947 - val_loss: 1.1198 - val_acc: 0.8507
# Epoch 188/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0074 - acc: 0.9965 - val_loss: 1.0952 - val_acc: 0.8557
# Epoch 189/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0233 - acc: 0.9930 - val_loss: 1.0795 - val_acc: 0.8507
# Epoch 190/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0103 - acc: 0.9965 - val_loss: 1.0842 - val_acc: 0.8458
# Epoch 191/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0231 - acc: 0.9947 - val_loss: 1.0941 - val_acc: 0.8358
# Epoch 192/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0251 - acc: 0.9938 - val_loss: 1.0323 - val_acc: 0.8408
# Epoch 193/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0218 - acc: 0.9930 - val_loss: 1.0684 - val_acc: 0.8507
# Epoch 194/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0211 - acc: 0.9912 - val_loss: 1.1055 - val_acc: 0.8507
# Epoch 195/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0234 - acc: 0.9947 - val_loss: 1.0615 - val_acc: 0.8408
# Epoch 196/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0200 - acc: 0.9938 - val_loss: 1.0136 - val_acc: 0.8358
# Epoch 197/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0314 - acc: 0.9930 - val_loss: 1.0327 - val_acc: 0.8358
# Epoch 198/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0174 - acc: 0.9947 - val_loss: 1.1454 - val_acc: 0.8408
# Epoch 199/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0240 - acc: 0.9930 - val_loss: 1.0724 - val_acc: 0.8557
# Epoch 200/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0164 - acc: 0.9938 - val_loss: 0.9566 - val_acc: 0.8657
# Epoch 201/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0113 - acc: 0.9956 - val_loss: 0.9771 - val_acc: 0.8607
# Epoch 202/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0219 - acc: 0.9956 - val_loss: 1.0266 - val_acc: 0.8557
# Epoch 203/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0087 - acc: 0.9974 - val_loss: 1.0519 - val_acc: 0.8408
# Epoch 204/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0332 - acc: 0.9930 - val_loss: 1.0369 - val_acc: 0.8507
# Epoch 205/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0202 - acc: 0.9921 - val_loss: 0.9545 - val_acc: 0.8756
# Epoch 206/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0165 - acc: 0.9947 - val_loss: 0.9767 - val_acc: 0.8607
# Epoch 207/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0354 - acc: 0.9930 - val_loss: 0.9801 - val_acc: 0.8706
# Epoch 208/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0185 - acc: 0.9912 - val_loss: 1.0229 - val_acc: 0.8607
# Epoch 209/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0227 - acc: 0.9956 - val_loss: 1.0548 - val_acc: 0.8458
# Epoch 210/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0150 - acc: 0.9956 - val_loss: 1.1129 - val_acc: 0.8358
# Epoch 211/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0100 - acc: 0.9982 - val_loss: 1.1528 - val_acc: 0.8358
# Epoch 212/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0106 - acc: 0.9974 - val_loss: 1.1410 - val_acc: 0.8408
# Epoch 213/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0130 - acc: 0.9982 - val_loss: 1.1163 - val_acc: 0.8458
# Epoch 214/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0117 - acc: 0.9965 - val_loss: 1.1037 - val_acc: 0.8408
# Epoch 215/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0103 - acc: 0.9974 - val_loss: 1.0961 - val_acc: 0.8408
# Epoch 216/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0192 - acc: 0.9938 - val_loss: 1.0628 - val_acc: 0.8458
# Epoch 217/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0186 - acc: 0.9938 - val_loss: 1.0376 - val_acc: 0.8657
# Epoch 218/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0181 - acc: 0.9938 - val_loss: 1.0353 - val_acc: 0.8706
# Epoch 219/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0116 - acc: 0.9974 - val_loss: 1.0991 - val_acc: 0.8607
# Epoch 220/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0077 - acc: 0.9974 - val_loss: 1.1437 - val_acc: 0.8507
# Epoch 221/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0318 - acc: 0.9938 - val_loss: 1.0301 - val_acc: 0.8557
# Epoch 222/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0267 - acc: 0.9947 - val_loss: 0.9728 - val_acc: 0.8706
# Epoch 223/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0224 - acc: 0.9956 - val_loss: 1.0042 - val_acc: 0.8607
# Epoch 224/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0214 - acc: 0.9938 - val_loss: 1.0426 - val_acc: 0.8507
# Epoch 225/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0155 - acc: 0.9956 - val_loss: 1.1091 - val_acc: 0.8408
# Epoch 226/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0127 - acc: 0.9956 - val_loss: 1.1123 - val_acc: 0.8458
# Epoch 227/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0153 - acc: 0.9956 - val_loss: 1.0918 - val_acc: 0.8657
# Epoch 228/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0182 - acc: 0.9947 - val_loss: 1.0658 - val_acc: 0.8507
# Epoch 229/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0231 - acc: 0.9938 - val_loss: 1.0721 - val_acc: 0.8607
# Epoch 230/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0216 - acc: 0.9956 - val_loss: 1.1061 - val_acc: 0.8507
# Epoch 231/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0144 - acc: 0.9947 - val_loss: 1.1057 - val_acc: 0.8408
# Epoch 232/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0145 - acc: 0.9938 - val_loss: 1.0837 - val_acc: 0.8358
# Epoch 233/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0153 - acc: 0.9956 - val_loss: 1.0834 - val_acc: 0.8259
# Epoch 234/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0113 - acc: 0.9956 - val_loss: 0.9932 - val_acc: 0.8607
# Epoch 235/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0113 - acc: 0.9974 - val_loss: 0.9880 - val_acc: 0.8557
# Epoch 236/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0129 - acc: 0.9965 - val_loss: 1.0349 - val_acc: 0.8458
# Epoch 237/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0099 - acc: 0.9974 - val_loss: 1.0732 - val_acc: 0.8507
# Epoch 238/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0189 - acc: 0.9956 - val_loss: 1.0928 - val_acc: 0.8458
# Epoch 239/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0113 - acc: 0.9965 - val_loss: 1.0558 - val_acc: 0.8557
# Epoch 240/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0063 - acc: 0.9982 - val_loss: 1.0613 - val_acc: 0.8706
# Epoch 241/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0048 - acc: 0.9982 - val_loss: 1.1034 - val_acc: 0.8706
# Epoch 242/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0181 - acc: 0.9974 - val_loss: 1.1346 - val_acc: 0.8657
# Epoch 243/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0112 - acc: 0.9974 - val_loss: 1.1142 - val_acc: 0.8607
# Epoch 244/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0101 - acc: 0.9956 - val_loss: 1.1030 - val_acc: 0.8507
# Epoch 245/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0254 - acc: 0.9956 - val_loss: 1.0226 - val_acc: 0.8607
# Epoch 246/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0266 - acc: 0.9930 - val_loss: 0.9807 - val_acc: 0.8806
# Epoch 247/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0054 - acc: 0.9982 - val_loss: 1.2442 - val_acc: 0.8358
# Epoch 248/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0140 - acc: 0.9965 - val_loss: 1.3779 - val_acc: 0.8109
# Epoch 249/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0316 - acc: 0.9912 - val_loss: 1.1568 - val_acc: 0.8557
# Epoch 250/300
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0266 - acc: 0.9947 - val_loss: 1.0264 - val_acc: 0.8657
# Epoch 251/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0175 - acc: 0.9947 - val_loss: 0.9971 - val_acc: 0.8507
# Epoch 252/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0294 - acc: 0.9921 - val_loss: 1.0891 - val_acc: 0.8159
# Epoch 253/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0229 - acc: 0.9938 - val_loss: 1.1051 - val_acc: 0.8109
# Epoch 254/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0272 - acc: 0.9930 - val_loss: 1.1562 - val_acc: 0.8209
# Epoch 255/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0187 - acc: 0.9930 - val_loss: 1.1787 - val_acc: 0.8308
# Epoch 256/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0246 - acc: 0.9921 - val_loss: 1.1327 - val_acc: 0.8308
# Epoch 257/300
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0253 - acc: 0.9930 - val_loss: 1.0916 - val_acc: 0.8458
# Epoch 258/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0117 - acc: 0.9965 - val_loss: 1.1155 - val_acc: 0.8408
# Epoch 259/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0231 - acc: 0.9930 - val_loss: 1.0298 - val_acc: 0.8607
# Epoch 260/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0200 - acc: 0.9956 - val_loss: 0.9970 - val_acc: 0.8557
# Epoch 261/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0259 - acc: 0.9895 - val_loss: 0.9855 - val_acc: 0.8806
# Epoch 262/300
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0189 - acc: 0.9947 - val_loss: 1.0686 - val_acc: 0.8557
# Epoch 263/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0219 - acc: 0.9938 - val_loss: 1.1415 - val_acc: 0.8458
# Epoch 264/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0275 - acc: 0.9956 - val_loss: 1.1308 - val_acc: 0.8507
# Epoch 265/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0068 - acc: 0.9982 - val_loss: 1.1025 - val_acc: 0.8557
# Epoch 266/300
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0157 - acc: 0.9921 - val_loss: 1.0004 - val_acc: 0.8706
# Epoch 267/300
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0207 - acc: 0.9912 - val_loss: 0.9768 - val_acc: 0.8706
# Epoch 268/300
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0158 - acc: 0.9938 - val_loss: 0.9882 - val_acc: 0.8657
# Epoch 269/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0214 - acc: 0.9947 - val_loss: 1.0717 - val_acc: 0.8657
# Epoch 270/300
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0178 - acc: 0.9965 - val_loss: 1.1673 - val_acc: 0.8507
# Epoch 271/300
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0320 - acc: 0.9930 - val_loss: 1.1204 - val_acc: 0.8657
# Epoch 272/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0288 - acc: 0.9930 - val_loss: 1.0678 - val_acc: 0.8557
# Epoch 273/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0284 - acc: 0.9947 - val_loss: 1.1179 - val_acc: 0.8408
# Epoch 274/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0326 - acc: 0.9912 - val_loss: 1.0343 - val_acc: 0.8607
# Epoch 275/300
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0155 - acc: 0.9947 - val_loss: 1.0123 - val_acc: 0.8657
# Epoch 276/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0150 - acc: 0.9947 - val_loss: 1.0258 - val_acc: 0.8657
# Epoch 277/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0240 - acc: 0.9938 - val_loss: 1.0187 - val_acc: 0.8706
# Epoch 278/300
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0136 - acc: 0.9938 - val_loss: 0.9958 - val_acc: 0.8806
# Epoch 279/300
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0188 - acc: 0.9938 - val_loss: 0.9996 - val_acc: 0.8706
# Epoch 280/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0198 - acc: 0.9912 - val_loss: 1.0748 - val_acc: 0.8557
# Epoch 281/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0255 - acc: 0.9938 - val_loss: 1.0829 - val_acc: 0.8507
# Epoch 282/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0390 - acc: 0.9877 - val_loss: 1.0464 - val_acc: 0.8557
# Epoch 283/300
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0142 - acc: 0.9974 - val_loss: 1.0142 - val_acc: 0.8607
# Epoch 284/300
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0229 - acc: 0.9912 - val_loss: 1.0233 - val_acc: 0.8557
# Epoch 285/300
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0198 - acc: 0.9947 - val_loss: 1.0462 - val_acc: 0.8507
# Epoch 286/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0121 - acc: 0.9974 - val_loss: 1.0370 - val_acc: 0.8607
# Epoch 287/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0241 - acc: 0.9930 - val_loss: 1.0126 - val_acc: 0.8756
# Epoch 288/300
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0166 - acc: 0.9947 - val_loss: 1.0257 - val_acc: 0.8706
# Epoch 289/300
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0065 - acc: 0.9974 - val_loss: 1.0784 - val_acc: 0.8607
# Epoch 290/300
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0164 - acc: 0.9930 - val_loss: 1.0758 - val_acc: 0.8657
# Epoch 291/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0069 - acc: 0.9974 - val_loss: 1.0719 - val_acc: 0.8706
# Epoch 292/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0163 - acc: 0.9921 - val_loss: 1.0763 - val_acc: 0.8756
# Epoch 293/300
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0072 - acc: 0.9991 - val_loss: 1.0681 - val_acc: 0.8856
# Epoch 294/300
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0147 - acc: 0.9956 - val_loss: 1.1146 - val_acc: 0.8756
# Epoch 295/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0143 - acc: 0.9938 - val_loss: 1.1679 - val_acc: 0.8657
# Epoch 296/300
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0205 - acc: 0.9921 - val_loss: 1.1941 - val_acc: 0.8657
# Epoch 297/300
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0287 - acc: 0.9921 - val_loss: 1.0282 - val_acc: 0.8806
# Epoch 298/300
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0299 - acc: 0.9921 - val_loss: 1.0522 - val_acc: 0.8607
# Epoch 299/300
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0123 - acc: 0.9965 - val_loss: 1.0440 - val_acc: 0.8557
# Epoch 300/300
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0083 - acc: 0.9965 - val_loss: 0.9985 - val_acc: 0.8607

# %%
x_test = test_data.paper_id.to_numpy()
GNN.evaluate(x=x_test, y=y_test)
# Out:
# 43/43 [==============================] - 1s 15ms/step - loss: 1.5295 - acc: 0.7940
# [1.5294572114944458, 0.7940102219581604]

# %% [markdown]
# Mucho mejor!
